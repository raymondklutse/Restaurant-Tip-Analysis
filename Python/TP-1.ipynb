# %% [markdown]
# # TP1 - A journey to Data Scientist

# %% [markdown]
# Report Submitted by <br>
# Raymond KLUTSE
# Ismail <br>

# %% [markdown]
# # Question 1

# %% [markdown]
# Known
# Data collected over 2.5 months in 1990
# Tips are a major component of a server’s pay
#
# Unknown
# The particular months of the year when the data was collected
# The region/ town where the data was collected
# The sex of the person receiving the tip
# Specific time of the day in time format
# Wether the week starts with Monday or Sunday

# %% [markdown]
# # Question 2

# %% [markdown]
# Why it is a good case study?
# Because there could be some factors that influence the amount of tips that servers receive and this could help the manager know how to improve this phenomenon.
# Encourages servers to stay in the restaurant business
#
# Important Factors
# Sex
# Size of the party
# Tip
# Total bill
# Day
# Server’s Sex

# %% [markdown]
# # Question 3

# %% [markdown]
# Question 3
# In this study, we would like to know the important factors that play a role in the tipping criteria of servers in the restaurant. From this data, we can find out how these factors affect the tipping and customer service/review from clients
# This can also influence the type of people HR employs as servers in the restaurant.
# We can also find out the specific time of the day  and day of the week when the tips increase and decrease.
# We can also find out if weekends influence tips.
#
# Main variable of interest
# Total Bill
#
# Questions
# Who is likely to get a tip?
# Who is likely to give a tip?
# Does the amount of the tip depend on the amount of the bill?
# Does the total bill on a specific affect the tips given?

# %% [markdown]
# # Question 4

# %% [markdown]
# Question 4
# Scales of measurement
# Total Bill - Ratio
# Tip - Ratio
# Sex - Nominal
# Smoker - Nominal
# Day - Ordinal
# Time - Nominal
# Size -Ratio/ Interval
#
# Format
# Total Bill - Float
# Tip - Float
# Sex -Integer/String
# Smoker - Integer/String
# Day - Integer/String
# Time - Float
# Size - Integer
#
# Role

# %% [markdown]
# # Question 5

# %% [markdown]
# Scales of measurement
# Total Bill - Ratio
# Tip - Ratio
# Sex - Nominal
# Smoker - Nominal
# Day - Ordinal
# Time - Ratio
# Size -Ratio/ Interval
#
# Format
# Total Bill - Float
# Tip - Float
# Sex -Integer
# Smoker - Integer
# Day - Integer
# Time - Float
# Size - Integer

# %%
import pandas as pd

# %%
df = pd.read_csv('tips.csv',header = None)
df.columns = ["obs","totbill","tip","sex","smoker","day","time","size"]

# %%
df.head()
# Out:
#    obs  totbill   tip  sex  smoker  day  time  size
# 0    1    16.99  1.01    1       0    6     0     2
# 1    2    10.34  1.66    0       0    6     0     3
# 2    3    21.01  3.50    0       0    6     0     3
# 3    4    23.68  3.31    0       0    6     0     2
# 4    5    24.59  3.61    1       0    6     0     4

# %%
df.describe()
# Out:
#               obs     totbill         tip         sex      smoker         day  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean   122.500000   19.785943    2.998279    0.356557    0.381148    4.725410
# std     70.580923    8.902412    1.383638    0.479967    0.486667    1.155774
# min      1.000000    3.070000    1.000000    0.000000    0.000000    3.000000
# 25%     61.750000   13.347500    2.000000    0.000000    0.000000    3.000000
# 50%    122.500000   17.795000    2.900000    0.000000    0.000000    5.000000
# 75%    183.250000   24.127500    3.562500    1.000000    1.000000    6.000000
# max    244.000000   50.810000   10.000000    1.000000    1.000000    6.000000
#
#              time        size
# count  244.000000  244.000000
# mean     0.278689    2.569672
# std      0.449276    0.951100
# min      0.000000    1.000000
# 25%      0.000000    2.000000
# 50%      0.000000    2.000000
# 75%      1.000000    3.000000
# ...

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_1407d638_ea73_11e9_9420_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1407d638_ea73_11e9_9420_acde48001122row0_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_1407d638_ea73_11e9_9420_acde48001122row0_col2 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1407d638_ea73_11e9_9420_acde48001122row0_col3 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_1407d638_ea73_11e9_9420_acde48001122row0_col4 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_1407d638_ea73_11e9_9420_acde48001122row0_col5 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_1407d638_ea73_11e9_9420_acde48001122row0_col6 {
#             background-color:  #f0cdbb;
#             color:  #000000;
# ...

# %% [markdown]
# From the correlation matrix above, we indentify a strong correlation between the total bill and the amount of tip given. There is also a subtle relation between the size of the party and the amount of tip given.

# %%
import seaborn as sns
# Create the default pairplot
sns.pairplot(df)

# %% [markdown]
# # Question 7
